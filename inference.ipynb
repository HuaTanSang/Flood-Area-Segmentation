# %%
from UNet_model import UNETModel
from inference_module import load_model, plot_results, inference
from dataset import FloodDataset

import torch 
import torch.nn as nn 
import random

# %%
checkpoint_dir = "/home/huatansang/Documents/UNET/UNET_checkpoint/best_model.pth"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
model = UNETModel(3, 1) 
model = load_model(checkpoint_dir, device, model)
# Out:
# Model has been loaded succesfully!

# %%
dataset = FloodDataset(root_folder="/home/huatansang/Documents/UNET/Flood")

random_indices = random.sample(range(len(dataset)), 10)
random_samples = [dataset[i] for i in random_indices]

# %%
for tuple in random_samples: 
    image = tuple['image']
    mask = tuple['mask']

    image, mask, pred = inference(image, mask, model, device)

    plot_results(image, mask, pred)
# Out:
# 0.8778342455043002
# 0.782267897578819
# 0.9535460992907802
# 0.9112165367671976
# 0.8686569088916113
# 0.7678103271400889
# 0.8501765596098874
# 0.739397484644633
# 0.9260099863822061
# 0.8622147083685545
# 0.9484058459335384
# 0.9018743992310158
# 0.09882990039648004
# 0.051983723296032555
# 0.9287587722407316
# 0.8669931180518793
# 0.7933103072168697
# 0.6574269358240434
# 0.9342600267805905
# 0.8766303697499103
